# %%
# !pip install PyPDF2
# !pip install python-docx
# Out:
# Requirement already satisfied: PyPDF2 in c:\programdata\anaconda3\lib\site-packages (1.26.0)
# Requirement already satisfied: python-docx in c:\programdata\anaconda3\lib\site-packages (0.8.10)
# Requirement already satisfied: lxml>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-docx) (4.5.0)

# %%
import PyPDF2 as pdf
import os
import docx

# %%
file = open('note.pdf','rb')

# %%
pdf_reader = pdf.PdfFileReader(file)

# %%
pdf_reader

# %%
pdf_reader.getNumPages()
# Out:
# 9

# %%
page=pdf_reader.getPage()
page.extractText()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0a0d9f56fae2> in <module>
# ----> 1 page=pdf_reader.getPage()
#       2 page.extractText()
#
# TypeError: getPage() missing 1 required positional argument: 'pageNumber'

# %%
for i in range(pdf_reader.numPages):
    page = pdf_reader.getPage(i)
    print(page.extractText())
# Out:
# SHORT NOTES
#  [1] The Giant™s garden :
#  The Giant was the owner of the garden.
#  It was a large and lovely garden, with soft-green g
# rass and beautiful flowers.
#  There were many trees that blossomed in the springt
# ime and had rich fruits in the autumn.
#  Birds of the trees sang so sweety that the children
#  would stop their games and listen to
# them.
#  Every afternoon, while returning from school, the c
# hildren used to go and play in the
# Gaint™s garden.
#  The Giant was not there in his castle.
# [2] The Selfishness of the Giant :
#  One day the Giant came back.
#   He was away for many years.
#   As soon as he returned to his castle, he saw the ch
# ildren playing in the garden.
#   He became very angry.
#   The children were frightened and they all ran away.
#   The Giant told that it was his garden and he would
# not allow anybody to go there.
#   He was so selfish that he built a high wall all aro
# und the garden to stop children from
# entering it.
#   He also put a notice on the gate : TRESPASSERS WILL
#  BE PROSECUTED
#   The poor children had now no where to play.
#  [3] The Shepherd™s Wit :
#  The shepherd was not literate but he was very witty
# .
#   He answered the king™s three questions wittily and
# pleased the king.
#   He proved the king™s value twenty five shillings.
#   In the beginning he also requested the king to pard
# on him if he said something displeasing
# to him.
#   In this way he made himself safe.
#   He could save his master™s life with his wit.
#   In the end he also proved how he was the servant of
#  the king too.
#   How witty the Shepherd was !
#  [4] King John and his three questions :
#  King John ruled over England seven hundren years ag
# o.
#   The Abbot of Canterbury was one of the priests in h
# is kingdom.
#   King John was displeased with him because people sa
# id that he was richer than the king.
#   So the king summoned him to his court.
#   He asked the Abbot if he kept a better house than h
# e did.
#   He also told that a priest should not be so rich.
#   A priest should be learned and wise, but not rich.
#   Then the king told the Abbot to answer his three qu
# estions or be ready to die.
#   He asked first question : How much am I worth ? Exa
# ctly how much ? Not a penny more,
# not a penny less.
#   The second question was : How long will it take me
# to go round the world ? and the third
# was : What am I thinking now ?
#   As the Abbot could not give immediate answers, he g
# ranted him three weeks time.
#
#
# [5] Canada :
#  Canada is the second largest country in area in the
#  world.
#   Canada became independent in 1867.
#   The name ‚Canada™ comes from the word ‚Kanata™ whic
# h means ‚village™ or ‚community™.
#  Most of the people are immigrants from Britain and
# France.
#  Their official languages are English and French.
#  Their Emblem includes three maple leaves.
#  A red, eleven pointed maple leaf is included in the
# ir flag.
#  The National Anthem is ‚O Canada .....™
#  It is a rich country in natural resources.
#  They are leading in the production of wheat, hydroe
# lectricity and paper-pulp.
# [6] Japan :
#  Japan is the country of the rising sun.
#  It is also called Nippon or Nihon which means the l
# and of the rising sun.
#  There is the red sun in their national flag too.
#  Their national Anthem is ‚Kimigayo™(The Reign of th
# eir Emperor).
#  Japan is famous for ‚Ikebana™,™Origami™and ‚Bonsai™
# .
#  Life in Japan reflects the culture of both the East
#  and the West.
#  Most of the Japanese wear western style clothing.
#  On festival and special occasions the people dress
# in traditional Kimonos.
#  They like to watch both traditional ‚No™ And ‚Kabuk
# i™ dramas and latest western plays and
# movies.
#  [7] The Indian flag :
#  The Indian flag is called tri-colour or chakradhvaj
# a.
#  It has three colours- the saffron, white and green.
#   The saffron suggests courage and sacrifice, the whi
# te truth and peace and the green stands
# for prosperity.
#  There is a wheel (chakra) in the centre of the flag
#  which suggests progress.
# [8] The effect of noise pollution :
#  Generally, when the sound is too loud and disturbin
# g, it is noise.
#  It is always annoying and harmful. A sound above 85
#  decibels damages humun ears.
#  It may result in hearing loss.
#  The human body never gets used to noise.
#  It causes illness and deafness.
#  After hearing loud noise a person may suffer from h
# igh blood pressure, annoyance, anxiety
# and heart disease.
#  Sometimes sudden and unexpected noise may cause ind
# igestion and gastric problems.
#  No one these days can escape the terror of noise.
# [9] How we can prevent noise pollution :
#  According to WHO report we can control noise pollut
# ion most easily.
#  There are some suggestions to prevent noise polluti
# on.
#  We should speak aloud, but not loudly.
#  We must avoid shouting. We should not slam books, d
# oors, etc.
#  We should avoid walking noisily. We should use only
#  one mechanical device at a time.
#  We should keep the volume of streos, radios, tap re
# corders and television sets low.
#
#
#  We must not blow horns loudly and necessarily.
#  We should observe the ‚Silence Zones™ near schools,
#  hospitals, etc.
#  We should make minimum use of microphones and loud
# speakers.
#  Thus we can make the world around us a quiter place
#  to live in.
#  [10] Qualities found in Mother :
#  The mother is a wonderful creation of God.
#  Her ability to do and endure is unimaginable.
#  She can compromise with any conditions and have pow
# er to thing reasonably.
#  She expresses her feelings with tears.
#  Her tears are something unique which are for pain,
# joy, pride, disappointment and
# loneliness.
#  Her kiss can cure everything-from a broken leg to a
#  broken heart.
# [11] The details of the wonderful creation :
#  The details of the wonderful creation are that.....
#   Her all parts should be movable and replaceable.
#  She has a lap which disappears when she stands up.
#  She has a skill to cure everything.
#  She is able to handle and feed the family with limi
# ted things.
#  She has three pairs of eyes and six pairs of hands.
#  [12] Diamond - an exceptional Stone :
#  Diamond is a stone, but it is an exceptional stone.
#   There are many glittering stones and gems, but no o
# ther stone is as valuable as the
# diamond.
#   It is used to adorn man™s figure and finger.
#   Diamonds are worn in rings, necklaces and watches b
# y man.
#   Diamond is a pure from of carbon.
#   It is the hardest substance and it never gets worn
# out, so it is used for cutting, drilling and
# engraving.
#   Diamond is valued according to its carat, colour, c
# ut and clarity.
#   Diamond earns a good amount of foreign exchange.
#   Really, Diamond is an exceptional stone.
#  [13] India™s exports of diamonds :
#  India has a major share in the world diamond and je
# wellery business.
#  It is said that 9 out of 10 diamonds set in jewelle
# ry are polished in India.
#  There is a rise in India™s export of diamonds with
# globalization.
#  The world market was opened to exporters.
#  The government has made the import of rough diamond
# s duty free and encouraged the
# export of polished diamonds.
#  Moreover the business persons took part in Internat
# ional Trade fairs and improved the
# quality.
#  Some training institutes of international standards
#  have been set up.
#  They have prepared skilled persons. Secondly, the d
# iamond industry is using modern
# machinery and technology, too.
#  We are earning a good amount of foreign exchange.
#  Thus India will be the gems and jewellery capital o
# f the world within some years.
#
#
# [14] The different uses of the Diamonds :
#  The diferent uses of the Diamonds are as follows :
#  They are used in different types of jewellery.
#  They are used as tools in modern industries bacause
#  of its hardness.
#  They are also used for engraving, cutting and drill
# ing.
#  Diamonds are used to make bulb filament, watches an
# d smoothing airplane runways.
# [15] The underwater boat :
#  The underwater boat is a magic item.
#   Take a transparent container filled with water.
#   Make a small boat out of aluminium foil, paper and
# a toothpick.
#   Put it on the surface of the water.
#   The boat flots. Then take a transparent plastic cup
# .
#   Place the cup over the boat.
#   Give the boat a gentle push down.
#   The boat goes down and moves under water.
#   It works on the principle of surface tension / forc
# e and motion.
#  [16] Floting Paper fish :
#  Take a piece of thick paper and cut it into a fish
# shape.
#  Make a small hole in the centre.
#  Then place the paper fish carefully into the bowl f
# illed with water.
#  Then put a drop of magic liquid into the centre cir
# cle.
#  Give a gentle push to make it float.
# [17] Helen - A gifted learner :
#  Helen keller was deaf, blind and dumb.
#   Since she was deaf, she didnot learn to speak.
#   At the age of seven, she got a teacher named Miss A
# nne Sullivan.
#   Helen was a quick learner.
#   She was quite anxious - curious to learn to speak a
# nd read.
#   Her teacher, Sullivan used the language based on
# sense of touch
# .
#  She uttered words and asked Helen to touch her lips
#  and throat.
#   Helen learnt to speak through the movements of the
# lips and the vibration in the throat.
#   Even at Redcliff College she learnt all her subject
# s with great courage and confidence.
#   Her teacher was the source of encouragement for her
# .
#   Helen was really an intelligent learner.
#   She was a gifted learner, though she was blind.
#   [18] TS-1 :
#  TS-1 was a strange looking complex vehicle.
#  It was called Time-Shuttle-1.
#  It was not a plane.
#  It was specially made to travel across time.
#  Even in the year 2094 A.D., TS-1 was still an exper
# imental vehicle.
#  Only the scientists and researchers used it in thos
# e years.
#  It once travelled to Jurassic age.
#  This shuttle had a time meter on its board that sho
# wed years in the dial.
#  It worked automatically.
# [19] The end of the story ‚Test of True Love™ :
#  Blandford came into contact with a lady named Meyne
# ll through a book called of Human
# Bondage.
#  Both of them had not seen eathother but both of the
# m wrote letters to each other regularly
# for thirteen months.
#  One day Blandford got a chance to meet Meynell.
#  He was told by her that she would be wearing a red
# rose.
#  Blandford was eagerly waiting at the railway statio
# n with the novel ‚Of Human Bondage™
# in his hand.
#  Blandford saw a beautiful lady in a green suit but
# she was not wearing a rose.
#  On the other hand he saw a woman past forty wearing
#  a red rose.
#  Blandford™s attention got divided between the young
#  lady in green and the old lady with
# the red rose.
#  He had a strong desire to go after the lady in gree
# n but on the other hand he wanted to be
# faithful to Meynell.
#  Finally, the old lady told him that the lady in gre
# en had told her to wear the red rose.
#  The old lady also told that if he invited her to di
# nner, she should tell him that she was
# waiting for her in the restaurant across the street
#  and the old lady added that it was a kind
# of test.
#
#  [20] Moving paper fish :
#  The participant girl takes the piece of thick paper
#  and cuts in the shape of a fish.
#  She makes a hole in the centre. She places the fish
#  in a bowl filled with water.
#  The fish floats but does not move.
#  Then the girl puts a drop of dishwashing liquid in
# the hole of the fish.
#  The dishwashing liquid spreads on the rear part and
#  it disturbs the surface tension there and
# so the fish moves forward.
#  This is based on the principle of force and motion.
#    [21] India™s place in the diamond market :
#  India has a major share in the world diamond and je
# wellery business.
#   9 out of 10 diamonds set in jewellery are polished
# in India.
#   India imports rough diamonds, cuts and polishes the
# m and exports them to other countries.
#   With globalization the world market was opened to e
# xporters.
#   The Indian government made the import of rough diam
# onds duty free and encouraged the
# export of polished diamonds.
#   Moreover, Indian business persons took part in Inte
# rnational Trade Fairs and improved the
# quality.
#   Even some training institutes of international stan
# dards have been set up in India.
#   These institutes have prepared skilled persons.
#   Secondly, the diamond industry is using modern mach
# inery and technology, too.
#   India is earning a good amount of foreign exchange.
#   Thus, India will be the gems and jewellery capital
# of the world within some years.
#
#
#
# [22] Dr. Franz Halberg™s views on Chronobiology :
#   Dr. Franz Halberg is the founder of chronobiology -
#  biology of time.
#  According to Dr. Franz our bodies have an internal
# music that we can and we should tune
# into.
#  Our intention is to live in harmony with nature. Bi
# orhythms provide us the basis for
# choosing the best time for our actions.
#  To be successful and to remain healthy it is necess
# ary that we think, feel and move in
# balanced cycles.
#  [23] Canada :
#   Canada became independent in 1867.
#  The name ‚Canada™ comes from the word ‚Kanata™ whic
# h means ‚village™ or ‚community™.
#  Most of the people of Canada are immigrants from Br
# itain and France.
#  The official languages of Canada are English and Fr
# ench.
#  The emblem of Canada includes three red maple leave
# s.
#  The National Anthem of Canada is ‚O Canada ........
# .™. It is rich in natural resources.
#  Canada is leading in the production of wheat, hydro
# electricity and paper pulp.
#  [24] Juliane, a girl of great courage :
#   While Juliane was going to Pucalpa to meet her fath
# er, her plane crashed.
#  She survived but was left alone in the forest.
#  She was badly injured and some of her bones had bro
# ken, so she was in great pain.
#  She had only a box of sweets and a Christmas cake f
# or food. However, she didn™t loose
# courage.
#  She saw a brook one day and decided to walk along i
# t as it would lead her to a river.
#  Finally she reached the river and saw a boat in it.
#   She also saw a hut near the river,Three men who wer
# e living in the hut found that she
# needed help and finally took her to her father.
#  Thus, after eleven and a half days Juliane met her
# father after facing a lot of difficulties
# bravely.
#   [25] The French scientists™ experiment on squirrel
# s :
#   Some French scientists did an experiment with squir
# rels.
#  They put sugar water in a naturally lighted room ev
# eryday at 10.00 a.m.
#  The squirrels came to drink the water exactly at th
# e right time.
#  Then the scientists started putting the sugar water
#  in a room that was artificially lighted for
# 24 hours.
#  They put the water at 8.00 p.m.
#  It took the squirrels one week to find out the swee
# t water.
#  Then they started coming in the evening instead of
# morning.
#  Then the scientists took the squirrels to New York.
#   They came out for their food when their bodies told
#  them, but it was only. 3.00 p.m. in
# New York.
#  Their bodies were still in ‚Paris time™.
#
#
# [26] Digvijay - a thoughtless person :
#
#   Digvijay got a chance to enter TS - 1 and visit the
#  Jurassic age.
#  Jignesh, the programme officer had given him all th
# e instructions.
#  He had also told Digvijay to follow instructions of
#  Amogh, the safety officer.
#  Even then Digvijay behaved in a senseless way.
#  Digvijay was waiting for the dinosaur with a camera
#  in his hand.
#  But when the dinosaur came in front of him and gave
#  out a loud roar, Digvijay got terribly
# frightened.
#  The camera fell down from his hands.
#  When the dinosaur roared again, Digvijay became ver
# y terrified.
#  He forgot the instructions and ran for his life.
#  He moved away from the trail and disappeared into t
# he forest.
#  When he returned back, he was covered with mud from
#  head to toe.
#  When everyone travelled back by TS-1 , they found t
# hat the things had changed.
#  Everyone looked at Digvijay™s muddy shoes and found
#  a lump of mud with a dead
# butterfly.
#
#  [27] Anne Sullivan - an extraordinary teacher :
#
#   Anne Sullivan was a teacher for the deaf and blind.
#   She was an excellent teacher.
#  She gave a new meaning to Helen™s life.
#  At first she gave Helen a doll to play with and the
# n after sometime she made some finger
# movements on Helen™s palm.
#  This excited Helen and she started learning spellin
# gs which were written on her palm.
#  This awakened Helen™s soul.
#  Miss Sullivan also taught Helen how to speak.
#  She would speak a word and ask Helen to touch her l
# ips and throat.
#  Thus she taught Helen to speak through the movement
# s of lips and the vibration in the
# throat.
#  She was such a great teacher that she sacrificed he
# r own eyesight to teach Helen.
#   [28] Effects of noise :
#
#   Any undesirable sound is noise.
#  It is always annoying and harmful.
#  A sound above 85 dbs can damage human ears.
#  It may result in hearing loss.
#  The human body never gets used to noise.
#  It causes illness and deafness.
#  After hearing a loud noise a person may suffer from
#  high blood pressure, annoyance,
# anxiety and heart disease.
#  Sometimes sudden and unexpected noise may cause ind
# igestion and gastric problems.
#
#
# [29] The Abbot of Canterbury :
#  King John was not pleased with Abbot because he had
#  heard that the Abbot was richer than
# he.
#  So the King told the Abbot that he would like to te
# st his intelligence.
#  The King asked the Abbot three questions and gave h
# im three weeks to find the answers.
#  The King also laid a condition that if the Abbot wa
# s not able to answer the questions, then
# he would die.
#  The Abbot was greatly worried.
#  He roamed here and there to find the answers to the
#  King™s questions, but he couldn™t get
# the answers from anywhere.
#  Finally, the clever shepherd who looked like the Ab
# bot, put on his clothes, went to the
# court and answered the King™s questions.
#  Then he asked the King to pardon the Abbot. The Kin
# g was pleased and so he pardoned the
# Abbot.
#
#  [30] Anne Sullivan - an extraordinary teacher :
#
#   Anne Sullivan was a teacher for the deaf and blind.
#   She was an excellent teacher.
#  She gave a new meaning to Helen™s life.
#  At first she gave Helen a doll to play with and the
# n after some time she made some finger
# movements on Helen™s palm.
#  This excited Helen and she started learning spellin
# gs which were written on her palm.
#  This awakened Helen™s soul.
#  Miss Sullivan also taught Helen how to speak a word
#  and ask Helen to touch her lips and
# throat.
#  Thus she taught Helen to speak through the movemnet
# s of lips and the vibration in the
# throat.
#  She was such a great teacher that she sacrificed he
# r own eyesight to teach Helen.
#   [31] Effects of noise :
#
#   Any undesirable sound is noise.
#  It is always annoying and harmful.
#  A sound above 85 dbs can damage human ears.
#  It may result in hearing loss.
#  The human body never gets used to noise .
#  It causes illness and deafness.
#  After hearing a loud noise a person may suffer from
#  high blood pressure, annoyance,
# anxiety and heart disease.
#  Sometimes sudden and unexpected noise may cause ind
# igestion and gastric problems.
#  [32] Juliane, a girl of great courage :
#  While Juliane was going to Pucalpa to meet her fath
# er, her plane crashed .
#  She survived but was left alone in the forest.
#  She was badly injured and some of her bones had bro
# ken , so she was in great pain .
#  She had only a box of sweets and a Christmas cake f
# or food.
#  However, she didn™t loose courage .
#  She saw brook one day and decided to walk along it
# as it would lead her to a river.
#  Finally she reached the river and saw a boat in it.
#   She also saw a hut near the river.
#  Three men who were living in the hut found that she
#  needed help and finally took her to
# her father.
#  Thus, after eleven and half days Juliane met her fa
# ther after facing a lot of difficulties
# bravely.

# %%
pdfdoc = 'note.pdf'
todoc = 'newdoc.docx'
word = win32com.client.Dispatch("word.Application")
word.visible = 1
wb1 = word.Documents.Open(pdfdoc)
wb1.SavesAs(todox, FileFormat = 16)
wb1.Close()
word.Quit()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-4-2bef8fb4b594> in <module>
#       3 word = win32com.client.Dispatch("word.Application")
#       4 word.visible = 1
# ----> 5 wb1 = word.Documents.Open(pdfdoc)
#       6 wb1.SavesAs(todox, FileFormat = 16)
#       7 wb1.Close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\win32com\client\dynamic.py in Open(self, FileName, ConfirmConversions, ReadOnly, AddToRecentFiles, PasswordDocument, PasswordTemplate, Revert, WritePasswordDocument, WritePasswordTemplate, Format, Encoding, Visible, OpenAndRepair, DocumentDirection, NoEncodingDialog, XMLTransform)
#
# com_error: (-2147352567, 'Exception occurred.', (0, 'Microsoft Word', "Sorry, we couldn't find your file. Was it moved, renamed, or deleted?\r (C:\\WINDOWS\\system32\\note.pdf)", 'wdmain11.chm', 24654, -2146823114), None)
